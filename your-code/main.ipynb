# %% [markdown]
# <a href="https://colab.research.google.com/github/NayelySaldivar/lab-parsing-api-rick/blob/master/your-code/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge: Rick and Morty API
#
# ![](http://as01.epimg.net/epik/imagenes/2019/02/12/portada/1549970850_227267_1549973816_noticia_normal.jpg)
#
#
# **In this challenge, you'll develop codes to parse and analyze data returned from the [Rick and Morty API](https://rickandmortyapi.com/).** The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://rickandmortyapi.com/api/location'

# %%
response = requests.get(url)
results = pd.json_normalize(response.json()['results'])
results.head()
# Out:
#    id               name           type        dimension  \
# 0   1      Earth (C-137)         Planet  Dimension C-137
# 1   2           Abadango        Cluster          unknown
# 2   3   Citadel of Ricks  Space station          unknown
# 3   4  Worldender's lair         Planet          unknown
# 4   5       Anatomy Park     Microverse  Dimension C-137
#
#                                            residents  \
# 0  [https://rickandmortyapi.com/api/character/38,...
# 1      [https://rickandmortyapi.com/api/character/6]
# 2  [https://rickandmortyapi.com/api/character/8, ...
# 3  [https://rickandmortyapi.com/api/character/10,...
# 4  [https://rickandmortyapi.com/api/character/12,...
#
#                                           url                   created
# 0  https://rickandmortyapi.com/api/location/1  2017-11-10T12:42:04.162Z
# 1  https://rickandmortyapi.com/api/location/2  2017-11-10T13:06:38.182Z
# 2  https://rickandmortyapi.com/api/location/3  2017-11-10T13:08:13.191Z
# ...

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
response = requests.get(url)
results = response.json()
total_pages = results['info']['pages']

df = pd.DataFrame()

for i in range(total_pages):
    url=f'https://rickandmortyapi.com/api/location?page={i+1}'
    response = requests.get(url)
    results = pd.json_normalize(response.json()['results'])
    flattened_data = results.set_index('id')

    print(f'Página {i+1}\nAñadiendo {flattened_data.shape[0]} registros')
    df = df.append(flattened_data)
    print('Tamaño del df:',df.shape)
    # Los prints fueron sólo para ayuda visual
# Out:
# Página 1
# Añadiendo 20 registros
# Tamaño del df: (20, 6)
# Página 2
# Añadiendo 20 registros
# Tamaño del df: (40, 6)
# Página 3
# Añadiendo 20 registros
# Tamaño del df: (60, 6)
# Página 4
# Añadiendo 20 registros
# Tamaño del df: (80, 6)
# Página 5
# Añadiendo 20 registros
# Tamaño del df: (100, 6)
# Página 6
# Añadiendo 20 registros
# Tamaño del df: (120, 6)
# Página 7
# Añadiendo 6 registros
# Tamaño del df: (126, 6)

# %%
df.head()
# Out:
#                  name           type        dimension  \
# id
# 1       Earth (C-137)         Planet  Dimension C-137
# 2            Abadango        Cluster          unknown
# 3    Citadel of Ricks  Space station          unknown
# 4   Worldender's lair         Planet          unknown
# 5        Anatomy Park     Microverse  Dimension C-137
#
#                                             residents  \
# id
# 1   [https://rickandmortyapi.com/api/character/38,...
# 2       [https://rickandmortyapi.com/api/character/6]
# 3   [https://rickandmortyapi.com/api/character/8, ...
# 4   [https://rickandmortyapi.com/api/character/10,...
# 5   [https://rickandmortyapi.com/api/character/12,...
#
#                                            url                   created
# id
# 1   https://rickandmortyapi.com/api/location/1  2017-11-10T12:42:04.162Z
# 2   https://rickandmortyapi.com/api/location/2  2017-11-10T13:06:38.182Z
# 3   https://rickandmortyapi.com/api/location/3  2017-11-10T13:08:13.191Z
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The character who appeared in most episodes (aside from Rick and Morty, of course!).
#
# * The total number of dead characters.
#
# * A list of all character origins (without duplicates).

# %%
# url  = 'https://rickandmortyapi.com/api/character'
# response = requests.get(url)
# results = response.json()
# # total_pages = results['info']['pages']
# results

# %%
# data = df.copy()
# data

# %%
# personajes = pd.DataFrame(df.residents.explode()).dropna().reset_index(drop = True)
# personajes['limpio'] = [personajes.residents[i].strip() for i in range(len(personajes))]
# personajes

# %%
personajes.limpio[:60]
# Out:
# 0      https://rickandmortyapi.com/api/character/38
# 1      https://rickandmortyapi.com/api/character/45
# 2      https://rickandmortyapi.com/api/character/71
# 3      https://rickandmortyapi.com/api/character/82
# 4      https://rickandmortyapi.com/api/character/83
# 5      https://rickandmortyapi.com/api/character/92
# 6     https://rickandmortyapi.com/api/character/112
# 7     https://rickandmortyapi.com/api/character/114
# 8     https://rickandmortyapi.com/api/character/116
# 9     https://rickandmortyapi.com/api/character/117
# 10    https://rickandmortyapi.com/api/character/120
# 11    https://rickandmortyapi.com/api/character/127
# 12    https://rickandmortyapi.com/api/character/155
# 13    https://rickandmortyapi.com/api/character/169
# 14    https://rickandmortyapi.com/api/character/175
# 15    https://rickandmortyapi.com/api/character/179
# 16    https://rickandmortyapi.com/api/character/186
# 17    https://rickandmortyapi.com/api/character/201
# ...

# %%
personajes.dropna()
# Out:
#                                          residents
# 0     https://rickandmortyapi.com/api/character/38
# 1     https://rickandmortyapi.com/api/character/45
# 2     https://rickandmortyapi.com/api/character/71
# 3     https://rickandmortyapi.com/api/character/82
# 4     https://rickandmortyapi.com/api/character/83
# ..                                             ...
# 831  https://rickandmortyapi.com/api/character/817
# 832  https://rickandmortyapi.com/api/character/274
# 833  https://rickandmortyapi.com/api/character/389
# 834  https://rickandmortyapi.com/api/character/215
# 835  https://rickandmortyapi.com/api/character/294
#
# [804 rows x 1 columns]
